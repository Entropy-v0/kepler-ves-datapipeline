# %%
import pandas as pd 


df = pd.read_csv("../data/raw/p2p_history.csv")

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4868 entries, 0 to 4867
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     4867 non-null   str
#  1   page          4868 non-null   int64
#  2   merchant      4868 non-null   str
#  3   banks         4868 non-null   str
#  4   price         4868 non-null   float64
#  5   min_limit     4868 non-null   float64
#  6   max_limit     4868 non-null   float64
#  7   available     4868 non-null   float64
#  8   orders        4868 non-null   int64
#  9   success_rate  4868 non-null   float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 380.4 KB

# %%
df_relacion = df[['price','available']]

print(df_relacion.mean())
# Out:
# price          660.745901
# available    14142.984712
# dtype: float64
