# %%
import pandas as pd 


df = pd.read_csv("../output/historial_p2p.csv")

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4205 entries, 0 to 4204
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timestamp   4205 non-null   str
#  1   pagina      4205 non-null   int64
#  2   cajero      4205 non-null   str
#  3   bancos      4205 non-null   str
#  4   precio      4205 non-null   float64
#  5   min_vta     4205 non-null   float64
#  6   max_vta     4205 non-null   float64
#  7   disponible  4205 non-null   float64
#  8   ordenes     4205 non-null   int64
#  9   exito       4205 non-null   float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 328.6 KB

# %%
print(df["precio"].mean())
# Out:
# 658.7889771700357
