# %%
import pandas as pd 


df = pd.read_csv("../output/p2p_history.csv")

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     153 non-null    str
#  1   page          153 non-null    int64
#  2   merchant      153 non-null    str
#  3   banks         153 non-null    str
#  4   price         153 non-null    float64
#  5   min_limit     153 non-null    float64
#  6   max_limit     153 non-null    float64
#  7   available     153 non-null    float64
#  8   orders        153 non-null    int64
#  9   success_rate  153 non-null    float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 12.1 KB

# %%
df_relacion = df[['price','available']]

print(df_relacion.mean())

df_relacion.
# Out:
# price         673.554752
# available    3808.541438
# dtype: float64
